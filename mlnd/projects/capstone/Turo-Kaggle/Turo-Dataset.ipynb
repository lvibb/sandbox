# %%
import pandas as pd
turo_pricing = pd.read_json('/Users/vlal/Documents/GitHub/sandbox/mlnd/projects/capstone/Turo-Kaggle/database.json', orient='columns')
turo_pricing['airportLocations']
# Out:
# 0       [{'searchPath': '/rentals/cars/dc/washington/a...
# 1       [{'searchPath': '/rentals/cars/nh/manchester/a...
# 2       [{'searchPath': '/rentals/cars/ca/san-jose/air...
# 3       [{'searchPath': '/rentals/cars/ca/san-diego/ai...
# 4       [{'searchPath': '/rentals/cars/hi/lihue/airpor...
# 5       [{'searchPath': '/rentals/cars/ca/van-nuys/air...
# 6       [{'searchPath': '/rentals/cars/ca/los-angeles/...
# 7       [{'searchPath': '/rentals/cars/ca/los-angeles/...
# 8       [{'searchPath': '/rentals/cars/ca/long-beach/a...
# 9       [{'searchPath': '/rentals/cars/ca/los-angeles/...
# 10      [{'searchPath': '/rentals/cars/ma/boston/airpo...
# 11      [{'searchPath': '/rentals/cars/ca/los-angeles/...
# 12      [{'searchPath': '/rentals/cars/ca/san-francisc...
# 13      [{'searchPath': '/rentals/cars/nh/manchester/a...
# 14      [{'searchPath': '/rentals/cars/ca/los-angeles/...
# 15      [{'searchPath': '/rentals/cars/dc/washington/a...
# ...

# %%
turo_pricing.head()
# Out:
#                                     airportLocations availability  \
# 0  [{'searchPath': '/rentals/cars/dc/washington/a...         None
# 1  [{'searchPath': '/rentals/cars/nh/manchester/a...         None
# 2  [{'searchPath': '/rentals/cars/ca/san-jose/air...
# 3  [{'searchPath': '/rentals/cars/ca/san-diego/ai...         None
# 4  [{'searchPath': '/rentals/cars/hi/lihue/airpor...         None
#
#                                               badges  \
# 0  [{'id': 4, 'value': 'gps', 'label': 'GPS'}, {'...
# 1  [{'id': 7, 'value': 'hybrid', 'label': 'EV / H...
# 2  [{'id': 4, 'value': 'gps', 'label': 'GPS'}, {'...
# 3  [{'id': 4, 'value': 'gps', 'label': 'GPS'}, {'...
# 4  [{'id': 5, 'value': 'aux_input', 'label': 'Aud...
#
#                                      basicCarDetails  businessClass  color  \
# 0  {'fuelGrade': {'value': 'PREMIUM', 'label': 'P...            0.0    RED
# 1  {'fuelGrade': {'value': 'REGULAR', 'label': 'R...            0.0  BLACK
# ...
